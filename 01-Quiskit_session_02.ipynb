# %% [markdown]
# <h1 align= 'center'>Qiskit Session 02</h1>

# %% [markdown]
# ### Table of contents
# - Quantum Entanglememnt

# %%
# Installing Libraries
# !pip install qiskit pylatexenc --quiet
# !pip install qiskit.ignis --quiet

# %%
# Importing Libraries
from qiskit import *
from qiskit.tools.monitor import  job_monitor
from qiskit.tools.visualization import plot_state_qsphere
from qiskit.visualization import plot_histogram, plot_bloch_multivector, array_to_latex

import numpy as np
from qiskit.extensions import Initialize
from qiskit.ignis.verification import marginal_counts
from qiskit.quantum_info import random_statevector
# Out:
# C:\Users\alamg\AppData\Local\Temp/ipykernel_8476/206650140.py:9: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#   from qiskit.ignis.verification import marginal_counts

# %% [markdown]
# ## Entanglement

# %%
# Create circuit
circuit = QuantumCircuit(2,2)                     # Circuit for one bit

# apply gates
circuit.h(0)
circuit.cx(0,1)

circuit.measure(0,0)                              # apply messurement
circuit.draw(initial_state = True, output='mpl')  # Draw after Messurement

# %%
# Run on Simulator
simulator = Aer.get_backend('aer_simulator')     # Select Simulator
circuit.save_statevector()                       # Save StateVector
qobj = assemble(circuit)                         # Assemble
job = simulator.run(circuit)                     # run the simulation
job_monitor(job)                                 # Monitor Job
result = job.result()                            # Get Result

# View State vector output
print("printing StateVector")
final_state = result.get_statevector()     # Get StateVector    
plot_bloch_multivector(final_state)        # Plot statevector
# Out:
# Job Status: job has successfully run
# printing StateVector

# %% [markdown]
# ## Heisenberg's Uncertainity principle
#
# ### Initialize a qubit in state |0> / Z basis / Standard basis / computational basis
#
# ### Measure in Z basis

# %%
# Create circuit
circuit = QuantumCircuit(1,1)                     # Circuit for one bit

# Measure in Z (default) basis
circuit.measure(0,0)    

circuit.draw(initial_state = True, output='mpl')  # Draw after Messurement

# %%
# Run on Simulator
simulator = Aer.get_backend('aer_simulator')     # Select Simulator
circuit.save_statevector()                       # Save StateVector
qobj = assemble(circuit)                         # Assemble
job = simulator.run(circuit)                     # run the simulation
job_monitor(job)                                 # Monitor Job
result = job.result()                            # Get Result

# Simulated counts output
counts = result.get_counts()       # Get counts
plot_histogram(counts)             # plot counts
# Out:
# Job Status: job has successfully run

# %% [markdown]
# ### Measure in X basis

# %%
# Create circuit
circuit = QuantumCircuit(1,1)                     # Circuit for one bit

# Measure in X basis
circuit.h(0)
circuit.measure(0,0)    

circuit.draw(initial_state = True, output='mpl')  # Draw after Messurement

# %%
# Run on Simulator
simulator = Aer.get_backend('aer_simulator')     # Select Simulator
circuit.save_statevector()                       # Save StateVector
qobj = assemble(circuit)                         # Assemble
job = simulator.run(circuit)                     # run the simulation
job_monitor(job)                                 # Monitor Job
result = job.result()                            # Get Result

# Simulated counts output
counts = result.get_counts()       # Get counts
plot_histogram(counts)             # plot counts
# Out:
# Job Status: job has successfully run

# %% [markdown]
# ### Measure in Y basis

# %%
# Create circuit
circuit = QuantumCircuit(1,1)                     # Circuit for one bit

# Measure in Y basis
circuit.sdg(0)
circuit.h(0)
circuit.measure(0,0)    

circuit.draw(initial_state = True, output='mpl')  # Draw after Messurement

# %%
# Run on Simulator
simulator = Aer.get_backend('aer_simulator')     # Select Simulator
circuit.save_statevector()                       # Save StateVector
qobj = assemble(circuit)                         # Assemble
job = simulator.run(circuit)                     # run the simulation
job_monitor(job)                                 # Monitor Job
result = job.result()                            # Get Result

# Simulated counts output
counts = result.get_counts()       # Get counts
plot_histogram(counts)             # plot counts
# Out:
# Job Status: job has successfully run

# %% [markdown]
# ### Initialize a qubit in state |+> / X basis / Hadamard basis
# - **Measure in Z basis**
# - **Measure in X basis**
# - **Measure in Y basis**
#
# ### Initialize a qubit in state |+> / Y basis / Circular basis
# - **Measure in Z basis**
# - **Measure in X basis**
# - **Measure in Y basis**
