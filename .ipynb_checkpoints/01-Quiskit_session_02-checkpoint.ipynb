# %% [markdown]
# <h1 align= 'center'>Qiskit Session 02</h1>

# %%
# Importing Libraries
from qiskit import *
from qiskit.tools.monitor import  job_monitor
from qiskit.tools.visualization import plot_state_qsphere
from qiskit.visualization import plot_histogram, plot_bloch_multivector, array_to_latex

import numpy as np
from qiskit.extensions import Initialize
from qiskit.ignis.verification import marginal_counts
from qiskit.quantum_info import random_statevector
# Out:
# C:\Users\alamg\AppData\Local\Temp/ipykernel_4688/206650140.py:9: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#   from qiskit.ignis.verification import marginal_counts

# %% [markdown]
# ## Access and Run on real device

# %%
# Create circuit
circuit = QuantumCircuit(2,2)                     # Circuit for one bit

# apply gates
circuit.h(0)
circuit.cx(0,1)

circuit.measure([0,1],[0,1])                              # apply messurement
circuit.draw(initial_state = True, output='mpl')  # Draw after Messurement

# %%
# Run on Simulator
simulator = Aer.get_backend('aer_simulator')     # Select Simulator
circuit.save_statevector()                       # Save StateVector
qobj = assemble(circuit)                         # Assemble
job = simulator.run(circuit)                     # run the simulation
job_monitor(job)                                 # Monitor Job
result = job.result()                            # Get Result

# View State vector output
print("printing State Vector")
final_state = result.get_statevector()     # Get StateVector    
plot_bloch_multivector(final_state)        # Plot statevector
# Out:
# Job Status: job has successfully run
# printing State Vector

# %%
# Simulated counts output
counts = result.get_counts()       # Get counts
plot_histogram(counts)             # plot counts

# %% [markdown]
# ## Super Dense Coding

# %% [markdown]
# ### Create entangled pair with 2 qubits

# %%
# Define Qubits
alice_qreg = QuantumRegister(1, name="alice")
bob_qreg = QuantumRegister(1, name="bob")

# Create Circuit
superdense_coding_circuit = QuantumCircuit(alice_qreg, bob_qreg)

# Apply Gates
superdense_coding_circuit.h(1)
superdense_coding_circuit.cx(1,0)

superdense_coding_circuit.barrier()
superdense_coding_circuit.draw(initial_state=True, output ='mpl')

# %% [markdown]
# ### Message That Alice want to send:
# - `00` --> Alice does Nothing
# - `01` --> Alice applies X gate
# - `10` --> Alice applies Z gate
# - `11` --> Alice applies X and Z gate

# %%
# Message to send
message = '10'

# Conditions
if message[1]=="1":
    superdense_coding_circuit.x(0)
if message[0]=="1":
    superdense_coding_circuit.z(1)
    
superdense_coding_circuit.barrier()
superdense_coding_circuit.draw(initial_state=True, output ='mpl')

# %% [markdown]
# ### Bob Decodes Alice's message

# %%
superdense_coding_circuit.cx(1,0)      # Bob applies cx gate
superdense_coding_circuit.h(1)         # Bob applies h gate
superdense_coding_circuit.draw(initial_state=True, output ='mpl')

# %% [markdown]
# ### Apply Measurement

# %%
superdense_coding_circuit.measure_all()
superdense_coding_circuit.draw(initial_state=True, output ='mpl')

# %%
# Creating a copy of super dense coding circuit for later use
import copy
second_superdense_coding_circuit = copy.deepcopy(superdense_coding_circuit)

# %%
# Run on Simulator
simulator = Aer.get_backend('aer_simulator')     # Select Simulator
superdense_coding_circuit.save_statevector()                       # Save StateVector
qobj = assemble(superdense_coding_circuit)                         # Assemble
job = simulator.run(superdense_coding_circuit)                     # run the simulation
job_monitor(job)                                 # Monitor Job
result = job.result()                            # Get Result

# Simulated counts output
counts = result.get_counts()       # Get counts
plot_histogram(counts)             # plot counts
# Out:
# Job Status: job has successfully run
